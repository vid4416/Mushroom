# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\Vidhya'

# %%
df=pd.read_csv(r'C:\Users\Vidhya\Downloads\mushrooms.csv')

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import pandas.util.testing as tm

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
df.dtypes
# Out:
# class                       int32
# cap-shape                   int32
# cap-surface                 int32
# cap-color                   int32
# bruises                     int32
# odor                        int32
# gill-attachment             int32
# gill-spacing                int32
# gill-size                   int32
# gill-color                  int32
# stalk-shape                 int32
# stalk-root                  int32
# stalk-surface-above-ring    int32
# stalk-surface-below-ring    int32
# stalk-color-above-ring      int32
# stalk-color-below-ring      int32
# veil-type                   int32
# veil-color                  int32
# ring-number                 int32
# ring-type                   int32
# spore-print-color           int32
# population                  int32
# habitat                     int32
# dtype: object

# %%
#We see that all the data is in object form, hence converting them to numerical using Label Encoder.

# %%
y=df['class']

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int64

# %%
df.shape
# Out:
# (8124, 23)

# %%
encodedOutput_y=LabelEncoder()
df=encodedOutput_y.fit_transform(y)

# %%
labelencoder=LabelEncoder()
for column in y:
    df[y]=labelencoder.fit_transform(df[y])

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-278-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#No null values in the data

# %%
import seaborn as sns

# %%
for col in df.columns: print(df[col].value_counts())
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64
# 5    3656
# 2    3152
# 3     828
# 0     452
# 4      32
# 1       4
# Name: cap-shape, dtype: int64
# 3    3244
# 2    2556
# 0    2320
# 1       4
# Name: cap-surface, dtype: int64
# 4    2284
# 3    1840
# 2    1500
# 9    1072
# 8    1040
# 0     168
# 5     144
# 1      44
# 6      16
# 7      16
# Name: cap-color, dtype: int64
# 0    4748
# 1    3376
# Name: bruises, dtype: int64
# 5    3528
# 2    2160
# 8     576
# 7     576
# 0     400
# 3     400
# 6     256
# 1     192
# 4      36
# Name: odor, dtype: int64
# 1    7914
# 0     210
# Name: gill-attachment, dtype: int64
# 0    6812
# 1    1312
# Name: gill-spacing, dtype: int64
# 0    5612
# 1    2512
# Name: gill-size, dtype: int64
# 0     1728
# 7     1492
# 10    1202
# 5     1048
# 2      752
# 3      732
# 9      492
# 4      408
# 1       96
# 11      86
# 6       64
# 8       24
# Name: gill-color, dtype: int64
# 1    4608
# 0    3516
# ...

# %%
df=df.drop('stalk-color-below-ring',axis=1)

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-above-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  veil-type  veil-color  \
# ...

# %%
sns.scatterplot(x='class',y='cap-shape',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='cap-shape'>

# %%
#we see that cap-shape data is equally distributed in class range.

# %%
sns.scatterplot(x='class',y='cap-surface',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='cap-surface'>

# %%
sns.scatterplot(x='class',y='cap-color',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='cap-color'>

# %%
sns.scatterplot(x='class',y='bruises',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='bruises'>

# %%
sns.scatterplot(x='class',y='odor',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='odor'>

# %%
sns.scatterplot(x='class',y='gill-attachment',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='gill-attachment'>

# %%
sns.scatterplot(x='class',y='gill-spacing',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='gill-spacing'>

# %%
sns.scatterplot(x='class',y='gill-size',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='gill-size'>

# %%
sns.scatterplot(x='class',y='gill-color',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='gill-color'>

# %%
sns.scatterplot(x='class',y='stalk-shape',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='stalk-shape'>

# %%
sns.scatterplot(x='class',y='stalk-root',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='stalk-root'>

# %%
sns.scatterplot(x='class',y='stalk-surface-above-ring',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='stalk-surface-above-ring'>

# %%
sns.scatterplot(x='class',y='stalk-surface-below-ring',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='stalk-surface-below-ring'>

# %%
sns.scatterplot(x='class',y='stalk-color-above-ring',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='stalk-color-above-ring'>

# %%
sns.scatterplot(x='class',y='veil-type',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='veil-type'>

# %%
sns.scatterplot(x='class',y='veil-color',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='veil-color'>

# %%
sns.scatterplot(x='class',y='ring-number',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='ring-number'>

# %%
sns.scatterplot(x='class',y='ring-type',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='ring-type'>

# %%
sns.scatterplot(x='class',y='spore-print-color',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='spore-print-color'>

# %%
sns.scatterplot(x='class',y='population',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='population'>

# %%
sns.scatterplot(x='class',y='habitat',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='habitat'>

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='black',fmt=".1f")
# Out:
# <AxesSubplot:>

# %%
#We see that class has maximum correlation with gill size(50%), 10% with cap shape,gill attachment,veil color, 20% with spore-print color, habitat and cap surface,30% with population

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=12)
plt.yticks(fontsize=10)
plt.title("Variables Summary")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Outcome of describe of dataset:
#Total number of rows and columns: 8 rows × 22 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int32
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %%
collist=df.columns.values
ncol=30
nrows=4
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist(i)],color='green',orient='v')
    plt.tight_layout
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-6d88a929d298> in <module>
#       5 for i in range(0,len(collist)):
#       6     plt.subplot(nrows,ncol,i+1)
# ----> 7     sns.boxplot(df[collist(i)],color='green',orient='v')
#       8     plt.tight_layout
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
plt.boxplot(df['cap-shape'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f11dfdc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f11ef4c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f11dfa60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f11efb80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f11efee0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['cap-surface'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f0ea26a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f0ea2d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f0ea2340>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f0eb0460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f0eb07c0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['cap-color'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f0f05430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f0f05af0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f0f050d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f0f0f1f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f0f0f550>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['bruises'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f0f57820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f0f57e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f0f57490>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f0f64580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f0f648e0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['odor'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f0fba0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f0fba790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f0fa9d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f0fbae50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f0fc51f0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['gill-attachment'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f1012790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f1012e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f1012430>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f101f550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f101f8b0>],
#  'means': []}

# %%
#Very less outlier

# %%
plt.boxplot(df['gill-spacing'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f1724fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f17356d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f1724cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f1735d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f1743130>],
#  'means': []}

# %%
#Very less outlier

# %%
plt.boxplot(df['gill-size'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f17898b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f1789f70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f17895b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f1795670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f17959d0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['gill-color'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f17ed190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f17ed850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f17dae50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f17edf10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f17f52b0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['stalk-shape'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f183ca00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f184c100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f183c700>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f184c7c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f184cb20>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['stalk-root'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f189e2e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f189e9a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f188ff40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f18aa0a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f18aa400>],
#  'means': []}

# %%
#We see outliers

# %%
plt.boxplot(df['stalk-surface-above-ring'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f18f79d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f19060d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f18f7670>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f1906790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f1906af0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['stalk-surface-below-ring'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f36a8760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f36a8e20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f36a8400>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f36b6520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f36b6880>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['stalk-color-above-ring'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f3708520>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f3708be0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f37081c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f37132e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f3713640>],
#  'means': []}

# %%
#We see many outliers

# %%
plt.boxplot(df['veil-type'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f3763be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f376f2e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f3763880>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f376f9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f376fd00>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['veil-color'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f37b9fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f37c66a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f37b9c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f37c6d60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f37d4100>],
#  'means': []}

# %%
#few outliers

# %%
plt.boxplot(df['ring-number'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f3817d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f3827490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f3817a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f3827af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f3827e50>],
#  'means': []}

# %%
#few outliers

# %%
plt.boxplot(df['ring-type'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f3885490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f3885b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f3885130>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f3890250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f38905b0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['spore-print-color'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f38dcb80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f38eb280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f38dc820>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f38eb940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f38ebca0>],
#  'means': []}

# %%
#No outliers

# %%
plt.boxplot(df['population'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f3947280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f3947970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f3938ee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f3951070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f39513d0>],
#  'means': []}

# %%
#few outliers

# %%
plt.boxplot(df['habitat'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f2f3999b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f2f39a71c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f2f3999790>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f2f39a7880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f2f39a7be0>],
#  'means': []}

# %%
#few outliers

# %%
df.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %%
#Outcome of skewness:Skewness threshold is taken as +/-0.5. Columns having skewness are:
#cap-shape,class,odor,gill-size,spore-print-color,gill-attachment,stalk-surface-above-ring,stalk-color-above-ring,veil-color,population.

# %%
sns.distplot(df["cap-shape"])
# Out:
# <AxesSubplot:xlabel='cap-shape', ylabel='Density'>

# %%
#Data is not normalised. Building blocks is out of normalised curve.

# %%
sns.distplot(df["cap-surface"])
# Out:
# <AxesSubplot:xlabel='cap-surface', ylabel='Density'>

# %%
#Data is not normalised. Building blocks is out of normalised curve.

# %%
sns.distplot(df["cap-color"])
# Out:
# <AxesSubplot:xlabel='cap-color', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["bruises"])
# Out:
# <AxesSubplot:xlabel='bruises', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["odor"])
# Out:
# <AxesSubplot:xlabel='odor', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["gill-attachment"])
# Out:
# <AxesSubplot:xlabel='gill-attachment', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["gill-spacing"])
# Out:
# <AxesSubplot:xlabel='gill-spacing', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["gill-size"])
# Out:
# <AxesSubplot:xlabel='gill-size', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["gill-color"])
# Out:
# <AxesSubplot:xlabel='gill-color', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["stalk-shape"])
# Out:
# <AxesSubplot:xlabel='stalk-shape', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["stalk-root"])
# Out:
# <AxesSubplot:xlabel='stalk-root', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["stalk-surface-above-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-surface-above-ring', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["stalk-surface-below-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-surface-below-ring', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["stalk-color-above-ring"])
# Out:
# <AxesSubplot:xlabel='stalk-color-above-ring', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["veil-type"])
# Out:
# <AxesSubplot:xlabel='veil-type', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["veil-color"])
# Out:
# <AxesSubplot:xlabel='veil-color', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["ring-number"])
# Out:
# <AxesSubplot:xlabel='ring-number', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["ring-type"])
# Out:
# <AxesSubplot:xlabel='ring-type', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["spore-print-color"])
# Out:
# <AxesSubplot:xlabel='spore-print-color', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["population"])
# Out:
# <AxesSubplot:xlabel='population', ylabel='Density'>

# %%
#Data is not normalised.

# %%
sns.distplot(df["habitat"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-233-8b73e2a25a76> in <module>
# ----> 1 sns.distplot(df["habitat"])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
#Data is not normalised.

# %%
delete=pd.DataFrame([["-0.5","bruises","No"],["-0.5","gill-color","No"],["-0.4","ring-type","No"]],columns=["Correlation with the Target","Column Name","Normalised"])

# %%
delete
# Out:
#   Correlation with the Target Column Name Normalised
# 0                        -0.5     bruises         No
# 1                        -0.5  gill-color         No
# 2                        -0.4   ring-type         No

# %%
from scipy.stats import zscore
import numpy as np

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-232-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
z=np.abs(zscore(dfContCols))

# %%
z.shape
# Out:
# (8124, 19)

# %%
print(df.shape)
# Out:
# (8124, 19)

# %%
loss_percent=((8124-0)/8124*100)

# %%
loss_percent
# Out:
# 100.0

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.head()
# Out:
# Empty DataFrame
# Columns: [class, cap-shape, cap-surface, cap-color, odor, gill-attachment, gill-spacing, gill-size, stalk-shape, stalk-root, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, veil-type, veil-color, ring-number, spore-print-color, population]
# Index: []

# %%
x
# Out:
# Empty DataFrame
# Columns: [class, cap-shape, cap-surface, cap-color, odor, gill-attachment, gill-spacing, gill-size, stalk-shape, stalk-root, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, veil-type, veil-color, ring-number, spore-print-color, population]
# Index: []

# %%
x.shape
# Out:
# (0, 18)

# %%
df_new
# Out:
# Empty DataFrame
# Columns: [class, cap-shape, cap-surface, cap-color, odor, gill-attachment, gill-spacing, gill-size, stalk-shape, stalk-root, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, veil-type, veil-color, ring-number, spore-print-color, population, habitat]
# Index: []

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
df=sc.fit_transform(df)
df
# Out:
# array([[ 1.0366127 ,  1.02971224,  0.14012794, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [-0.96468045,  1.02971224,  0.14012794, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-0.96468045, -2.08704716,  0.14012794, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.96468045, -0.8403434 ,  0.14012794, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [ 1.0366127 , -0.21699152,  0.95327039, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [-0.96468045,  1.02971224,  0.14012794, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-230-36551c5c498c> in <module>
#       1 for i in range(0,1000):
# ----> 2     x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
#       3     lr.fit(x_train,y_train)
#       4     pred_train=lr.predict(x_train)
#       5     pred_test=lr.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
# -> 2175     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
#    2176                                               default_test_size=0.25)
#    2177
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
# ...

# %%
lr.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-225-1785cf3deb61> in <module>
# ----> 1 lr.score(x_test,y_test)
#
# NameError: name 'x_test' is not defined

# %%
import pickle
filename='Mushroom.pkl'
pickle.dump(lr,open(filename,'wb'))

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({"original":a,"predicted":predicted},index=range(len(a)))
df_com
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-279-30b56e964814> in <module>
#       1 import numpy as np
# ----> 2 a=np.array(y_test)
#       3 predicted=np.array(lr.predict(x_test))
#       4 df_com=pd.DataFrame({"original":a,"predicted":predicted},index=range(len(a)))
#       5 df_com
#
# NameError: name 'y_test' is not defined
